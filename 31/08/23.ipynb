# %%
/---- LCM & HCF --------/

a=20
b=15
l1=[]
l2=[]
for i in range(1,a+1):
  if a%i==0:
    l1.append(i)
for i in range(1,b+1):
  if b%i==0:
    l2.append(i)
l3=[]
for i in l1:
  if i in l2:
    l3.append(i)
print(max(l3))
print(a*b/5)
# Out:
# 5
# 60.0

# %%
def fact(a,b):
  l1=[]
  l2=[]
  for i in range(1,a+1):
    if a%i==0:
      l1.append(i)
  for i in range(1,b+1):
    if b%i==0:
      l2.append(i)
  l3=[]
  for i in l1:
    if i in l2:
      l3.append(i)
  print(max(l3))
fact(15,20)
# Out:
# 5

# %%
def fact(a,b):
  l1=[]
  l2=[]
  for i in range(1,a+1):
    if a%i==0:
      l1.append(i)
  for i in range(1,b+1):
    if b%i==0:
      l2.append(i)
  l3=[]
  for i in l1:
    if i in l2:
      l3.append(i)
  print(max(l3))
fact(15,20)
# Out:
# 5

# %%
/---- trailing zeros --------/


def trail(n):
  n1=str(n)
  n2=n1[::-1]
  c=0
  for i in n2:
    if i=="0":
      c+=1
    else:
      break;
  print(c)
trail(123000)
# Out:
# 3

# %%
def trail(n):
  n1=str(n)
  n2=n1[::-1]
  c=0
  for i in n2:
    if i=="0":
      c+=1
    else:
      break;
  print(c)
trail(576789)
# Out:
# 0
